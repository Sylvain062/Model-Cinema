# %%
#///////////////////////
# realisateurs //////////////////////
#///////////////////////////////////////////
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
import re
import unicodedata
from unidecode import unidecode
os.chdir('D:\Sylvain\GitHub\Model-Cinema')
#***********************************************************************
df=pd.read_csv('Data/Archives/V8.csv', sep=';',index_col='ID')
df = df.drop('Column1', axis=1)

# 'on enlève les accents des acteurs'#
df['acteur_1']=df['acteur_1'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['acteur_1']=df['acteur_1'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['acteur_1'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['acteur_1']=df['acteur_1'].apply(unidecode) #on enlève les accents
df['acteur_1']=df['acteur_1'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['acteur_2']=df['acteur_2'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['acteur_2']=df['acteur_2'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['acteur_2'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['acteur_2']=df['acteur_2'].apply(unidecode) #on enlève les accents
df['acteur_2']=df['acteur_2'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['acteur_3']=df['acteur_3'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['acteur_3']=df['acteur_3'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['acteur_3'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['acteur_3']=df['acteur_3'].apply(unidecode) #on enlève les accents
df['acteur_3']=df['acteur_3'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['acteur_4']=df['acteur_4'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['acteur_4']=df['acteur_4'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['acteur_4'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['acteur_4']=df['acteur_4'].apply(unidecode) #on enlève les accents
df['acteur_4']=df['acteur_4'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX


# 'on enlève les accents des realisateurs'#
df['real_1']=df['real_1'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['real_1']=df['real_1'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['real_1'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['real_1']=df['real_1'].apply(unidecode) #on enlève les accents
df['real_1']=df['real_1'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['real_2']=df['real_2'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['real_2']=df['real_2'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['real_2'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['real_2']=df['real_2'].apply(unidecode) #on enlève les accents
df['real_2']=df['real_2'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['real_3']=df['real_3'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['real_3']=df['real_3'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['real_3'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['real_3']=df['real_3'].apply(unidecode) #on enlève les accents
df['real_3']=df['real_3'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

# 'on enlève les accents des scenaristes'#
df['scen_1']=df['scen_1'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['scen_1']=df['scen_1'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['scen_1'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['scen_1']=df['scen_1'].apply(unidecode) #on enlève les accents
df['scen_1']=df['scen_1'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['scen_2']=df['scen_2'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['scen_2']=df['scen_2'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['scen_2'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['scen_2']=df['scen_2'].apply(unidecode) #on enlève les accents
df['scen_2']=df['scen_2'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['scen_3']=df['scen_3'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
df['scen_3']=df['scen_3'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['scen_3'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['scen_3']=df['scen_3'].apply(unidecode) #on enlève les accents
df['scen_3']=df['scen_3'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX

df['scen_4']=df['scen_4'].replace('\n', '', regex=True) # on enlève les \n au début des noms de star
# df['scen_4']=df['scen_4'].str.replace(' ', '', regex=True) # on enlève tous les espaces
df['scen_4'].fillna('XXXX', inplace=True) # ca sert à éviter de faire planter le split si valeur Nan
df['scen_4']=df['scen_4'].apply(unidecode) #on enlève les accents
df['scen_4']=df['scen_4'].replace('XXXX',np.NaN,regex=True) # et je retire les XXXX
df.to_csv('Data/allocineV8-SB.csv')
